# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

from datetime import date, datetime, timedelta

# %%
df_stock_ta = pd.read_csv('temp/stock_ta.csv')
df_stock_cdl = pd.read_csv('temp/stock_cdl.csv')
df_ind_ta = pd.read_csv('temp/ind_ta.csv')
df_ind_cdl = pd.read_csv('temp/ind_cdl.csv')
df_stock_news = pd.read_csv('temp/stock_news.csv')
df_ind_news = pd.read_csv('temp/ind_news.csv')

df_tar = pd.read_csv('temp/target.csv')
df_tar = df_tar[['report_date', 'ticker', 'label']]
# df_stock_ta = df_stock_ta.drop(['open', 'high', 'low', 'close', 'volume', 'adjusted_close'], axis = 1)
# df_ind_ta = df_ind_ta.drop(['open', 'high', 'low', 'close', 'volume', 'adjusted_close'], axis = 1)

# Prepare Cross Industrial Feature
df_inds = df_ind_cdl.merge(df_ind_news, on = ['inds', 'report_date'], how = 'left')
df_inds = df_inds.merge(df_ind_ta, on = ['report_date', 'inds'])
df_inds = df_inds.fillna(method = 'ffill')

# %% [markdown]
# # LSTM prediction

# %%
period = 7; train_size = 0.8; prepare_3d = False
require_features = ['cdl', 'ta', 'news']
inds_num = len(df_inds['inds'].unique())

price_cols = ['open', 'high', 'low', 'close', 'volume']
cdl_cols = ['morning_star', 'evening_star', 'hammer',
       'inverted_hammer', 'bullish_engulfing', 'bearish_engulfing',
       'shooting_star', 'hanging_man']
news_cols = ['compound', 'neg', 'neu', 'pos', 'new_cases',
       'total_cases', 'total_deaths', 'new_deaths', 'total_deaths_nd']
ta_cols = df_stock_ta.drop(['report_date', 'ticker'], axis = 1).columns

# %%
# Prepare Train test dataset preparation
X_train, y_train, X_test, y_test = [], [], [], []

stocks = df_tar['ticker'].unique()
for stock in stocks:
    
    print('Current Stock: ', stock)
    temp_stock_cdl = df_stock_cdl[df_stock_cdl['ticker'] == stock]
    temp_stock_ta = df_stock_ta[df_stock_ta['ticker'] == stock]
    temp_stock_news = df_stock_news[df_stock_news['ticker'] == stock]
    temp_stock_tar = df_tar[df_tar['ticker'] == stock]
    
    # Merge results
    data = temp_stock_tar.merge(temp_stock_cdl, on = ['report_date', 'ticker'])
    data = data.merge(temp_stock_ta, on = ['report_date', 'ticker'])
    data = data.merge(temp_stock_news, on = ['report_date', 'ticker'], how = 'left')
    data = data.fillna(method = 'ffill')
    
    check = True
    for i in range(period, len(data)):
        
        temp = []
        # Create historical data (within period)
        temp_period = data.iloc[i - period:i,]
        if temp_period.isnull().sum().sum() > 0:
            continue

        # Create stock feature space
        feature_dfs = []
        feature_dfs.append(temp_period[price_cols])
        
        if 'cdl' in require_features:
            feature_dfs.append(temp_period[cdl_cols])
            
        if 'news' in require_features:
            feature_dfs.append(temp_period[news_cols])
            
        if 'ta' in require_features:
            feature_dfs.append(temp_period[ta_cols])
            
        temp_stock_feature = pd.concat(feature_dfs, axis = 1).to_numpy()
        temp.append(temp_stock_feature)
        
        # Get industrial feature space
        for ind in sorted(list(df_inds['inds'].unique())):
            temp_period_inds = df_inds[df_inds['inds'] == ind].reset_index(drop = True).iloc[i - period:i,]
            
            feature_ind_dfs = []
            feature_ind_dfs.append(temp_period_inds[price_cols])
            if 'cdl' in require_features:
                feature_ind_dfs.append(temp_period_inds[cdl_cols])

            if 'news' in require_features:
                feature_ind_dfs.append(temp_period_inds[news_cols])

            if 'ta' in require_features:
                feature_ind_dfs.append(temp_period_inds[ta_cols])
                
            temp_ind_feature = pd.concat(feature_ind_dfs, axis = 1).to_numpy()
            temp.append(temp_ind_feature)
        
        # Create label 
        y_label = temp_period.iloc[-1]['label']
        
        if i <= int((len(data) - period) * train_size):
            
#             if check:
#                 print('train', i)
#                 print('max report_date: ', max(temp_period['report_date']), 'min report_date: ', min(temp_period['report_date']))
#                 print('Whole feature shape: ', np.array(temp).shape)
#                 print('label: ', y_label)
#                 check = False

            X_train.append(temp)
            y_train.append(y_label)
        else: 
            X_test.append(temp)
            y_test.append(y_label)
        
X_train, y_train = np.array(X_train).astype('float32'), np.array(y_train)
X_test, y_test = np.array(X_test).astype('float32'), np.array(y_test)
# Out:
# Current Stock:  MMM
# Current Stock:  AOS
# Current Stock:  ABT
# Current Stock:  ABBV
# Current Stock:  ABMD
# Current Stock:  ACN
# Current Stock:  ATVI
# Current Stock:  ADM
# Current Stock:  ADBE
# Current Stock:  ADP
# Current Stock:  AAP
# Current Stock:  AES
# Current Stock:  AFL
# Current Stock:  A
# Current Stock:  APD
# Current Stock:  AKAM
# Current Stock:  ALK
# Current Stock:  ALB
# Current Stock:  ARE
# Current Stock:  ALGN
# Current Stock:  ALLE
# Current Stock:  LNT
# Current Stock:  ALL
# Current Stock:  GOOGL
# Current Stock:  GOOG
# Current Stock:  MO
# Current Stock:  AMZN
# Current Stock:  AMCR
# Current Stock:  AMD
# Current Stock:  AEE
# Current Stock:  AAL
# Current Stock:  AEP
# Current Stock:  AXP
# Current Stock:  AIG
# Current Stock:  AMT
# Current Stock:  AWK
# Current Stock:  AMP
# Current Stock:  ABC
# Current Stock:  AME
# Current Stock:  AMGN
# Current Stock:  APH
# Current Stock:  ADI
# Current Stock:  ANSS
# Current Stock:  AON
# Current Stock:  APA
# Current Stock:  AAPL
# Current Stock:  AMAT
# Current Stock:  APTV
# Current Stock:  ANET
# Current Stock:  AJG
# Current Stock:  AIZ
# Current Stock:  T
# Current Stock:  ATO
# Current Stock:  ADSK
# Current Stock:  AZO
# Current Stock:  AVB
# Current Stock:  AVY
# Current Stock:  BKR
# Current Stock:  BALL
# Current Stock:  BAC
# Current Stock:  BBWI
# Current Stock:  BAX
# Current Stock:  BDX
# Current Stock:  WRB
# Current Stock:  BRK-B
# Current Stock:  BBY
# Current Stock:  BIO
# Current Stock:  TECH
# Current Stock:  BIIB
# Current Stock:  BLK
# Current Stock:  BK
# Current Stock:  BA
# Current Stock:  BKNG
# Current Stock:  BWA
# Current Stock:  BXP
# Current Stock:  BSX
# Current Stock:  BMY
# Current Stock:  AVGO
# Current Stock:  BR
# Current Stock:  BRO
# Current Stock:  BF-B
# Current Stock:  CHRW
# Current Stock:  CDNS
# Current Stock:  CZR
# Current Stock:  CPT
# Current Stock:  CPB
# Current Stock:  COF
# Current Stock:  CAH
# Current Stock:  KMX
# Current Stock:  CCL
# Current Stock:  CARR
# Current Stock:  CTLT
# Current Stock:  CAT
# Current Stock:  CBOE
# Current Stock:  CBRE
# Current Stock:  CDW
# Current Stock:  CE
# Current Stock:  CNC
# Current Stock:  CNP
# Current Stock:  CDAY
# Current Stock:  CF
# Current Stock:  CRL
# Current Stock:  SCHW
# Current Stock:  CHTR
# Current Stock:  CVX
# Current Stock:  CMG
# Current Stock:  CB
# Current Stock:  CHD
# Current Stock:  CI
# Current Stock:  CINF
# Current Stock:  CTAS
# Current Stock:  CSCO
# Current Stock:  C
# Current Stock:  CFG
# Current Stock:  CTXS
# Current Stock:  CLX
# Current Stock:  CME
# Current Stock:  CMS
# Current Stock:  KO
# Current Stock:  CTSH
# Current Stock:  CL
# Current Stock:  CMCSA
# Current Stock:  CMA
# Current Stock:  CAG
# Current Stock:  COP
# Current Stock:  ED
# Current Stock:  STZ
# Current Stock:  CEG
# Current Stock:  COO
# Current Stock:  CPRT
# Current Stock:  GLW
# Current Stock:  CTVA
# Current Stock:  COST
# Current Stock:  CTRA
# Current Stock:  CCI
# Current Stock:  CSX
# Current Stock:  CMI
# Current Stock:  CVS
# Current Stock:  DHI
# Current Stock:  DHR
# Current Stock:  DRI
# Current Stock:  DVA
# Current Stock:  DE
# Current Stock:  DAL
# Current Stock:  XRAY
# Current Stock:  DVN
# Current Stock:  DXCM
# Current Stock:  FANG
# Current Stock:  DLR
# Current Stock:  DFS
# Current Stock:  DISH
# Current Stock:  DIS
# Current Stock:  DG
# Current Stock:  DLTR
# Current Stock:  D
# Current Stock:  DPZ
# Current Stock:  DOV
# Current Stock:  DOW
# Current Stock:  DTE
# Current Stock:  DUK
# Current Stock:  DRE
# Current Stock:  DD
# Current Stock:  DXC
# Current Stock:  EMN
# Current Stock:  ETN
# Current Stock:  EBAY
# Current Stock:  ECL
# Current Stock:  EIX
# Current Stock:  EW
# Current Stock:  EA
# Current Stock:  ELV
# Current Stock:  LLY
# Current Stock:  EMR
# Current Stock:  ENPH
# Current Stock:  ETR
# Current Stock:  EOG
# Current Stock:  EPAM
# Current Stock:  EFX
# Current Stock:  EQIX
# Current Stock:  EQR
# Current Stock:  ESS
# Current Stock:  EL
# Current Stock:  ETSY
# Current Stock:  RE
# Current Stock:  EVRG
# Current Stock:  ES
# Current Stock:  EXC
# Current Stock:  EXPE
# Current Stock:  EXPD
# Current Stock:  EXR
# Current Stock:  XOM
# Current Stock:  FFIV
# Current Stock:  FDS
# Current Stock:  FAST
# Current Stock:  FRT
# Current Stock:  FDX
# Current Stock:  FITB
# Current Stock:  FRC
# Current Stock:  FE
# Current Stock:  FIS
# Current Stock:  FISV
# Current Stock:  FLT
# Current Stock:  FMC
# Current Stock:  F
# Current Stock:  FTNT
# Current Stock:  FTV
# Current Stock:  FBHS
# Current Stock:  FOXA
# Current Stock:  FOX
# Current Stock:  BEN
# Current Stock:  FCX
# Current Stock:  GRMN
# Current Stock:  IT
# Current Stock:  GNRC
# Current Stock:  GD
# Current Stock:  GE
# Current Stock:  GIS
# Current Stock:  GM
# Current Stock:  GPC
# Current Stock:  GILD
# Current Stock:  GL
# Current Stock:  GPN
# Current Stock:  GS
# Current Stock:  HAL
# Current Stock:  HIG
# Current Stock:  HAS
# Current Stock:  HCA
# Current Stock:  PEAK
# Current Stock:  HSIC
# Current Stock:  HSY
# Current Stock:  HES
# Current Stock:  HPE
# Current Stock:  HLT
# Current Stock:  HOLX
# Current Stock:  HD
# Current Stock:  HON
# Current Stock:  HRL
# Current Stock:  HST
# Current Stock:  HWM
# Current Stock:  HPQ
# Current Stock:  HUM
# Current Stock:  HBAN
# Current Stock:  HII
# Current Stock:  IBM
# Current Stock:  IEX
# Current Stock:  IDXX
# Current Stock:  ITW
# Current Stock:  ILMN
# Current Stock:  INCY
# Current Stock:  IR
# Current Stock:  INTC
# Current Stock:  ICE
# Current Stock:  IP
# Current Stock:  IPG
# Current Stock:  IFF
# Current Stock:  INTU
# Current Stock:  ISRG
# Current Stock:  IVZ
# Current Stock:  IQV
# Current Stock:  IRM
# Current Stock:  JBHT
# Current Stock:  JKHY
# Current Stock:  J
# Current Stock:  JNJ
# Current Stock:  JCI
# Current Stock:  JPM
# Current Stock:  JNPR
# Current Stock:  K
# Current Stock:  KDP
# Current Stock:  KEY
# Current Stock:  KEYS
# Current Stock:  KMB
# Current Stock:  KIM
# Current Stock:  KMI
# Current Stock:  KLAC
# Current Stock:  KHC
# Current Stock:  KR
# Current Stock:  LHX
# Current Stock:  LH
# Current Stock:  LRCX
# Current Stock:  LW
# Current Stock:  LVS
# Current Stock:  LDOS
# Current Stock:  LEN
# Current Stock:  LNC
# Current Stock:  LIN
# Current Stock:  LYV
# Current Stock:  LKQ
# Current Stock:  LMT
# Current Stock:  L
# Current Stock:  LOW
# Current Stock:  LUMN
# Current Stock:  LYB
# Current Stock:  MTB
# Current Stock:  MRO
# Current Stock:  MPC
# Current Stock:  MKTX
# Current Stock:  MAR
# Current Stock:  MMC
# Current Stock:  MLM
# Current Stock:  MAS
# Current Stock:  MA
# Current Stock:  MTCH
# Current Stock:  MKC
# Current Stock:  MCD
# Current Stock:  MCK
# Current Stock:  MDT
# Current Stock:  MRK
# Current Stock:  META
# Current Stock:  MET
# Current Stock:  MTD
# Current Stock:  MGM
# Current Stock:  MCHP
# Current Stock:  MU
# Current Stock:  MSFT
# Current Stock:  MAA
# Current Stock:  MRNA
# Current Stock:  MHK
# Current Stock:  MOH
# Current Stock:  TAP
# Current Stock:  MDLZ
# Current Stock:  MPWR
# Current Stock:  MNST
# Current Stock:  MCO
# Current Stock:  MS
# Current Stock:  MOS
# Current Stock:  MSI
# Current Stock:  MSCI
# Current Stock:  NDAQ
# Current Stock:  NTAP
# Current Stock:  NFLX
# Current Stock:  NWL
# Current Stock:  NEM
# Current Stock:  NWSA
# Current Stock:  NWS
# Current Stock:  NEE
# Current Stock:  NLSN
# Current Stock:  NKE
# Current Stock:  NI
# Current Stock:  NDSN
# Current Stock:  NSC
# Current Stock:  NTRS
# Current Stock:  NOC
# Current Stock:  NLOK
# Current Stock:  NCLH
# Current Stock:  NRG
# Current Stock:  NUE
# Current Stock:  NVDA
# Current Stock:  NVR
# Current Stock:  NXPI
# Current Stock:  ORLY
# Current Stock:  OXY
# Current Stock:  ODFL
# Current Stock:  OMC
# Current Stock:  ON
# Current Stock:  OKE
# Current Stock:  ORCL
# Current Stock:  OGN
# Current Stock:  OTIS
# Current Stock:  PCAR
# Current Stock:  PKG
# Current Stock:  PARA
# Current Stock:  PH
# Current Stock:  PAYX
# Current Stock:  PAYC
# Current Stock:  PYPL
# Current Stock:  PENN
# Current Stock:  PNR
# Current Stock:  PEP
# Current Stock:  PKI
# Current Stock:  PFE
# Current Stock:  PM
# Current Stock:  PSX
# Current Stock:  PNW
# Current Stock:  PXD
# Current Stock:  PNC
# Current Stock:  POOL
# Current Stock:  PPG
# Current Stock:  PPL
# Current Stock:  PFG
# Current Stock:  PG
# Current Stock:  PGR
# Current Stock:  PLD
# Current Stock:  PRU
# Current Stock:  PEG
# Current Stock:  PTC
# Current Stock:  PSA
# Current Stock:  PHM
# Current Stock:  PVH
# Current Stock:  QRVO
# Current Stock:  PWR
# Current Stock:  QCOM
# Current Stock:  DGX
# Current Stock:  RL
# Current Stock:  RJF
# Current Stock:  RTX
# Current Stock:  O
# Current Stock:  REG
# Current Stock:  REGN
# Current Stock:  RF
# Current Stock:  RSG
# Current Stock:  RMD
# Current Stock:  RHI
# Current Stock:  ROK
# Current Stock:  ROL
# Current Stock:  ROP
# Current Stock:  ROST
# Current Stock:  RCL
# Current Stock:  SPGI
# Current Stock:  CRM
# Current Stock:  SBAC
# Current Stock:  SLB
# Current Stock:  STX
# Current Stock:  SEE
# Current Stock:  SRE
# Current Stock:  NOW
# Current Stock:  SHW
# Current Stock:  SBNY
# Current Stock:  SPG
# Current Stock:  SWKS
# Current Stock:  SJM
# Current Stock:  SNA
# Current Stock:  SEDG
# Current Stock:  SO
# Current Stock:  LUV
# Current Stock:  SWK
# Current Stock:  SBUX
# Current Stock:  STT
# Current Stock:  STE
# Current Stock:  SYK
# Current Stock:  SIVB
# Current Stock:  SYF
# Current Stock:  SNPS
# Current Stock:  SYY
# Current Stock:  TMUS
# Current Stock:  TROW
# Current Stock:  TTWO
# Current Stock:  TPR
# Current Stock:  TGT

# %%
print('X_train shape: ', X_train.shape)
print('y_train shape: ', y_train.shape)
print('X_test shape: ', X_test.shape)
print('y_test shape: ', y_test.shape)

# %%
# Divide to multiple combinations
cond_dict = {}
feature_idx_dict = {name: ind for ind, name in enumerate(pd.concat(feature_dfs, axis = 1).columns)}
adj_news_cols = ['compound', 'pos', 'new_deaths', 'new_deaths_nd']

# Candlestick + TA + News
feature_idx = [idx for name, idx in feature_idx_dict.items() \
                   if name in price_cols + cdl_cols + adj_news_cols + list(ta_cols)]
cond_dict['All'] = {'train': X_train[:, :, :, feature_idx], 'test': X_test[:, :, :, feature_idx]}

# Candlestick + News
feature_idx = [idx for name, idx in feature_idx_dict.items() if name in price_cols + cdl_cols + adj_news_cols]
cond_dict['Candlestick+News'] = {'train': X_train[:, :, :, feature_idx], 'test': X_test[:, :, :, feature_idx]}

# Candlestick + TA
feature_idx = [idx for name, idx in feature_idx_dict.items() if name in price_cols + cdl_cols + list(ta_cols)]
cond_dict['Candlestick+TA'] = {'train': X_train[:, :, :, feature_idx], 'test': X_test[:, :, :, feature_idx]}

# Candlestick Only
feature_idx = [idx for name, idx in feature_idx_dict.items() if name in price_cols + cdl_cols]
cond_dict['CandlestickOnly'] = {'train': X_train[:, :, :, feature_idx], 'test': X_test[:, :, :, feature_idx]}

# %% [markdown]
# ## LSTM

# %%
def lstm(input_shape):
    
    # LSTM model
    model = models.Sequential()
    model.add(layers.LSTM(50, activation = 'relu', input_shape = input_shape))
    model.add(layers.Dense(1, activation = 'sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %%
for feature_type, data in cond_dict.items():

    print(f'---- {feature_type} ----')
    temp_train = data['train']
    temp_test = data['test']

    if not prepare_3d:
        temp_train = temp_train.reshape(temp_train.shape[0], period, -1)
        temp_test = temp_test.reshape(temp_test.shape[0], period, -1)

    model = lstm((temp_train.shape[1], temp_train.shape[2]))
    history = model.fit(temp_train, y_train, epochs=4, validation_split=0.2)

    print('Training Accuracy')
    print(model.evaluate(temp_train, y_train))

    print('Testing Accuracy')
    print(model.evaluate(temp_test, y_test))
# Out:
# ---- All ----
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/4
# 2022-11-07 14:59:47.519982: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.6196
# 2022-11-07 15:02:25.570370: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - 166s 60ms/step - loss: 0.6934 - accuracy: 0.6196 - val_loss: 0.6590 - val_accuracy: 0.6326
# Epoch 2/4
# 2734/2734 [==============================] - 289s 106ms/step - loss: 0.6483 - accuracy: 0.6371 - val_loss: 0.6439 - val_accuracy: 0.6318
# Epoch 3/4
# 2734/2734 [==============================] - 400s 146ms/step - loss: 0.6413 - accuracy: 0.6423 - val_loss: 0.6411 - val_accuracy: 0.6433
# Epoch 4/4
# 2734/2734 [==============================] - 369s 135ms/step - loss: 0.6212 - accuracy: 0.6580 - val_loss: 0.6165 - val_accuracy: 0.6708
# Training Accuracy
# 3418/3418 [==============================] - 66s 19ms/step - loss: 0.6084 - accuracy: 0.6754
# [0.6084175705909729, 0.6754153966903687]
# Testing Accuracy
# 1328/1328 [==============================] - 24s 18ms/step - loss: 1.2248 - accuracy: 0.4570
# [1.2247940301895142, 0.4569525718688965]
# ---- Candlestick+News ----
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/4
# 2022-11-07 15:21:51.576969: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - ETA: 0s - loss: 0.6626 - accuracy: 0.6084
# 2022-11-07 15:27:54.683929: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - 380s 138ms/step - loss: 0.6626 - accuracy: 0.6084 - val_loss: 0.6465 - val_accuracy: 0.6309
# Epoch 2/4
# 2734/2734 [==============================] - 511s 187ms/step - loss: 0.6416 - accuracy: 0.6392 - val_loss: 0.6562 - val_accuracy: 0.6265
# Epoch 3/4
# 2734/2734 [==============================] - 427s 156ms/step - loss: 0.6360 - accuracy: 0.6433 - val_loss: 0.6301 - val_accuracy: 0.6471
# Epoch 4/4
# 2734/2734 [==============================] - 251s 92ms/step - loss: 0.6237 - accuracy: 0.6533 - val_loss: 0.6193 - val_accuracy: 0.6570
# Training Accuracy
# 3418/3418 [==============================] - 42s 12ms/step - loss: 0.6149 - accuracy: 0.6622
# [0.6149066686630249, 0.6621825695037842]
# Testing Accuracy
# 1328/1328 [==============================] - 16s 12ms/step - loss: 1.1272 - accuracy: 0.3933
# [1.127211332321167, 0.3932639956474304]
# ---- Candlestick+TA ----
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/4
# 2022-11-07 15:49:01.520396: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - ETA: 0s - loss: 0.6730 - accuracy: 0.6300
# 2022-11-07 15:53:07.365478: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - 254s 93ms/step - loss: 0.6730 - accuracy: 0.6300 - val_loss: 0.6467 - val_accuracy: 0.6364
# Epoch 2/4
# 2734/2734 [==============================] - 295s 108ms/step - loss: 0.6416 - accuracy: 0.6402 - val_loss: 0.6528 - val_accuracy: 0.6301
# Epoch 3/4
# 2734/2734 [==============================] - 446s 163ms/step - loss: 0.6178 - accuracy: 0.6643 - val_loss: 0.6042 - val_accuracy: 0.6773
# Epoch 4/4
# 2734/2734 [==============================] - 325s 119ms/step - loss: 0.5858 - accuracy: 0.6960 - val_loss: 0.5830 - val_accuracy: 0.6923
# Training Accuracy
# 3418/3418 [==============================] - 43s 12ms/step - loss: 0.5690 - accuracy: 0.7044
# [0.568978488445282, 0.7044143080711365]
# Testing Accuracy
# 1328/1328 [==============================] - 17s 13ms/step - loss: 0.9520 - accuracy: 0.4996
# [0.9519954323768616, 0.4995999038219452]
# ---- CandlestickOnly ----
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/4
# 2022-11-07 16:12:05.435772: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.6587
# 2022-11-07 16:16:44.303175: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - 293s 107ms/step - loss: 0.6152 - accuracy: 0.6587 - val_loss: 0.5577 - val_accuracy: 0.7166
# Epoch 2/4
# 2734/2734 [==============================] - 438s 160ms/step - loss: 0.5424 - accuracy: 0.7235 - val_loss: 0.5344 - val_accuracy: 0.7249
# Epoch 3/4
# 2734/2734 [==============================] - 433s 158ms/step - loss: 0.5240 - accuracy: 0.7360 - val_loss: 0.5304 - val_accuracy: 0.7310
# Epoch 4/4
# 2734/2734 [==============================] - 437s 160ms/step - loss: 0.5149 - accuracy: 0.7427 - val_loss: 0.5188 - val_accuracy: 0.7418
# Training Accuracy
# 3418/3418 [==============================] - 88s 26ms/step - loss: 0.5043 - accuracy: 0.7500
# [0.5042543411254883, 0.7499565482139587]
# Testing Accuracy
# 1328/1328 [==============================] - 27s 20ms/step - loss: 0.9743 - accuracy: 0.5431
# [0.974292516708374, 0.5430710315704346]

# %% [markdown]
# ## Simple RNN

# %%
# Simple RNN
def simpleRNN(input_shape):
    
    # LSTM model
    model = models.Sequential()
    model.add(layers.SimpleRNN(50, input_shape = input_shape, activation = 'relu'))

    model.add(layers.Dense(1, activation = 'sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

model = simpleRNN((temp_train.shape[1], temp_train.shape[2]))
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 13>()
#       9     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      11     return model
# ---> 13 model = simpleRNN((temp_train.shape[1], temp_train.shape[2]))
#      14 model.summary()
#
# NameError: name 'temp_train' is not defined

# %%
# Simple RNN
def simpleRNN(input_shape):
    
    # LSTM model
    model = models.Sequential()
    model.add(layers.SimpleRNN(50, input_shape = input_shape, activation = 'relu'))

    model.add(layers.Dense(1, activation = 'sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

prepare_3d = False
for feature_type, data in cond_dict.items():

    print(f'---- {feature_type} ----')
    temp_train = data['train']
    temp_test = data['test']

    if not prepare_3d:
        temp_train = temp_train.reshape(temp_train.shape[0], period, -1)
        temp_test = temp_test.reshape(temp_test.shape[0], period, -1)

    model = simpleRNN((temp_train.shape[1], temp_train.shape[2]))
    history = model.fit(temp_train, y_train, epochs=5)

    print('Training Accuracy')
    print(model.evaluate(temp_train, y_train))

    print('Testing Accuracy')
    print(model.evaluate(temp_test, y_test))
